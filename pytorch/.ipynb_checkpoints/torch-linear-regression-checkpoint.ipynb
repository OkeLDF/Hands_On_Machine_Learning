# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

from IPython.display import display, Markdown

import numpy as np
import torch

# %% [markdown]
# # Using Tensors and Autograd

# %% [markdown]
# ## Data

# %%
housing = fetch_california_housing()

X_train, X_test, y_train, y_test = train_test_split(housing.data, housing.target, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, random_state=42, test_size=0.1)

# %%
print(f'{X_train.shape=}')
print(f'{X_test.shape=}')
print(f'{X_val.shape=}')
print()
print(f'{y_train.shape=}')
print(f'{y_test.shape=}')
print(f'{y_val.shape=}')
# Out:
# X_train.shape=(13932, 8)
# X_test.shape=(5160, 8)
# X_val.shape=(1548, 8)
#
# y_train.shape=(13932,)
# y_test.shape=(5160,)
# y_val.shape=(1548,)

# %%
X_train = torch.FloatTensor(X_train)
X_val = torch.FloatTensor(X_val)
X_test = torch.FloatTensor(X_test)

means = X_train.mean(dim=0, keepdims=True)
stds = X_train.std(dim=0, keepdims=True)

X_train = (X_train - means) / stds
X_val = (X_val - means) / stds
X_test = (X_test - means) / stds

# %%
y_train = torch.FloatTensor(y_train).reshape(-1, 1)
y_val = torch.FloatTensor(y_val).reshape(-1, 1)
y_test = torch.FloatTensor(y_test).reshape(-1, 1)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Parameters initialization

# %%
torch.manual_seed(42)
n_features = X_train.shape[1]  # 8
weights = torch.randn((n_features, 1), requires_grad=True)
bias = torch.tensor(0., requires_grad=True)

# %%
def print_linear_func():
    equation_str = 'f(x) = '
    equation_str += ' + '.join(list(map(
        lambda item: f'{item[1][0]:.2f}x_{item[0]}',
        enumerate(weights.tolist(), start=1)
    )))
    equation_str += f' + {bias.item()}'

    try:
        display(Markdown(f'${equation_str}$'))
    except NameError:
        print(equation_str)

# %%
print_linear_func()  # randomly initiated
# Out:
# $f(x) = 0.34x_1 + 0.13x_2 + 0.23x_3 + 0.23x_4 + -1.12x_5 + -0.19x_6 + 2.21x_7 + -0.64x_8 + 0.0$

# %% [markdown]
# ### Training

# %%
learning_rate = 0.4
n_epochs = 100

for epoch in range(n_epochs):
    y_pred = X_train @ weights + bias  # calculates prediction

    loss = ((y_pred - y_train) ** 2).mean()  # MSE
    loss.backward()

    with torch.no_grad():
        bias -= learning_rate * bias.grad
        weights -= learning_rate * weights.grad
        bias.grad.zero_()
        weights.grad.zero_()

    print(f'Epoch {epoch+1:3}/{n_epochs}, Loss: {loss.item()}')
# Out:
# Epoch   1/100, Loss: 15.992842674255371
# Epoch   2/100, Loss: 4.682830810546875
# Epoch   3/100, Loss: 2.1424787044525146
# Epoch   4/100, Loss: 1.2740927934646606
# Epoch   5/100, Loss: 0.9412086009979248
# Epoch   6/100, Loss: 0.8018259406089783
# Epoch   7/100, Loss: 0.735872209072113
# Epoch   8/100, Loss: 0.6991417407989502
# Epoch   9/100, Loss: 0.6748808026313782
# Epoch  10/100, Loss: 0.6565617322921753
# Epoch  11/100, Loss: 0.6415442228317261
# Epoch  12/100, Loss: 0.6286912560462952
# Epoch  13/100, Loss: 0.617459774017334
# Epoch  14/100, Loss: 0.6075484156608582
# Epoch  15/100, Loss: 0.5987609028816223
# Epoch  16/100, Loss: 0.5909507870674133
# Epoch  17/100, Loss: 0.5839995741844177
# Epoch  18/100, Loss: 0.5778065919876099
# Epoch  19/100, Loss: 0.5722846984863281
# Epoch  20/100, Loss: 0.5673576593399048
# Epoch  21/100, Loss: 0.5629581212997437
# Epoch  22/100, Loss: 0.5590269565582275
# Epoch  23/100, Loss: 0.5555118322372437
# Epoch  24/100, Loss: 0.5523662567138672
# Epoch  25/100, Loss: 0.5495496392250061
# Epoch  26/100, Loss: 0.5470253825187683
# Epoch  27/100, Loss: 0.5447617173194885
# Epoch  28/100, Loss: 0.5427300930023193
# Epoch  29/100, Loss: 0.5409052968025208
# Epoch  30/100, Loss: 0.5392650961875916
# Epoch  31/100, Loss: 0.5377896428108215
# Epoch  32/100, Loss: 0.536461353302002
# Epoch  33/100, Loss: 0.5352646708488464
# Epoch  34/100, Loss: 0.5341855883598328
# Epoch  35/100, Loss: 0.5332120060920715
# Epoch  36/100, Loss: 0.532332718372345
# Epoch  37/100, Loss: 0.5315380692481995
# Epoch  38/100, Loss: 0.5308194160461426
# Epoch  39/100, Loss: 0.5301688313484192
# Epoch  40/100, Loss: 0.5295795798301697
# Epoch  41/100, Loss: 0.5290454030036926
# Epoch  42/100, Loss: 0.5285606980323792
# Epoch  43/100, Loss: 0.5281206965446472
# Epoch  44/100, Loss: 0.5277210474014282
# Epoch  45/100, Loss: 0.5273576378822327
# Epoch  46/100, Loss: 0.5270270109176636
# Epoch  47/100, Loss: 0.5267259478569031
# Epoch  48/100, Loss: 0.5264516472816467
# Epoch  49/100, Loss: 0.526201605796814
# Epoch  50/100, Loss: 0.5259735584259033
# Epoch  51/100, Loss: 0.5257653594017029
# Epoch  52/100, Loss: 0.5255751609802246
# Epoch  53/100, Loss: 0.5254013538360596
# Epoch  54/100, Loss: 0.5252423882484436
# Epoch  55/100, Loss: 0.5250969529151917
# Epoch  56/100, Loss: 0.5249637961387634
# Epoch  57/100, Loss: 0.5248419046401978
# Epoch  58/100, Loss: 0.5247301459312439
# Epoch  59/100, Loss: 0.5246276259422302
# Epoch  60/100, Loss: 0.5245335102081299
# Epoch  61/100, Loss: 0.5244472026824951
# Epoch  62/100, Loss: 0.5243679881095886
# Epoch  63/100, Loss: 0.5242952704429626
# Epoch  64/100, Loss: 0.5242283344268799
# Epoch  65/100, Loss: 0.5241668224334717
# Epoch  66/100, Loss: 0.5241101980209351
# Epoch  67/100, Loss: 0.5240581631660461
# Epoch  68/100, Loss: 0.5240103006362915
# Epoch  69/100, Loss: 0.5239661931991577
# Epoch  70/100, Loss: 0.5239255428314209
# Epoch  71/100, Loss: 0.523888111114502
# Epoch  72/100, Loss: 0.523853600025177
# Epoch  73/100, Loss: 0.5238217711448669
# Epoch  74/100, Loss: 0.5237924456596375
# Epoch  75/100, Loss: 0.5237653851509094
# Epoch  76/100, Loss: 0.5237404704093933
# Epoch  77/100, Loss: 0.52371746301651
# Epoch  78/100, Loss: 0.52369624376297
# Epoch  79/100, Loss: 0.5236765146255493
# Epoch  80/100, Loss: 0.5236583948135376
# Epoch  81/100, Loss: 0.5236417055130005
# Epoch  82/100, Loss: 0.5236262083053589
# Epoch  83/100, Loss: 0.5236119031906128
# Epoch  84/100, Loss: 0.5235987305641174
# Epoch  85/100, Loss: 0.5235865116119385
# Epoch  86/100, Loss: 0.5235751867294312
# Epoch  87/100, Loss: 0.5235647559165955
# Epoch  88/100, Loss: 0.5235550999641418
# Epoch  89/100, Loss: 0.5235461592674255
# Epoch  90/100, Loss: 0.5235379338264465
# Epoch  91/100, Loss: 0.5235302448272705
# Epoch  92/100, Loss: 0.5235232710838318
# Epoch  93/100, Loss: 0.5235166549682617
# Epoch  94/100, Loss: 0.5235106348991394
# Epoch  95/100, Loss: 0.5235050916671753
# Epoch  96/100, Loss: 0.5234999060630798
# Epoch  97/100, Loss: 0.523495078086853
# Epoch  98/100, Loss: 0.5234906077384949
# Epoch  99/100, Loss: 0.5234865546226501
# Epoch 100/100, Loss: 0.5234827399253845

# %%
print_linear_func()
# Out:
# $f(x) = 0.86x_1 + 0.12x_2 + -0.32x_3 + 0.37x_4 + -0.00x_5 + -0.05x_6 + -0.88x_7 + -0.86x_8 + 2.069737434387207$

# %% [markdown]
# ### Prediction

# %%
X_new = X_test[:3]
X_new
# Out:
# tensor([[-1.1522, -0.2859, -0.5005, -0.1674, -0.0279,  0.0772,  0.1947,  0.2852],
#         [-0.7065,  0.1102, -0.1620,  0.2087,  0.1230, -0.0343, -0.2362,  0.0602],
#         [-0.2091,  1.8527, -0.5864,  0.1920, -0.0995, -0.1572,  1.0096, -1.4302]])

# %%
with torch.no_grad():
    y_pred = X_new @ weights + bias

# %%
y_pred
# Out:
# tensor([[0.7306],
#         [1.7652],
#         [2.7173]])

# %% [markdown]
# ### Evaluating

# %%
with torch.no_grad():
    y_pred = X_test @ weights + bias

# %%
print('RMSE:', np.sqrt(mean_squared_error(y_test.numpy(), y_pred.numpy())).item())
print('  r²:', r2_score(y_test.numpy(), y_pred.numpy()))
# Out:
# RMSE: 0.7354057464293138
#   r²: 0.5912830829620361

# %% [markdown]
# # Using Pytorch's High-Level API

# %% [markdown]
# ## nn.Modules

# %%
import torch.nn as nn

# %%
torch.manual_seed(42)

model = nn.Linear(
    in_features=n_features,
    out_features=1
)

# %%
def print_model_linear_func():
    equation_str = 'f(x) = '
    equation_str += ' + '.join(list(map(
        lambda item: f'{item[1]:.2f}x_{item[0]}',
        enumerate(model.weight.tolist()[0], start=1)
    )))
    equation_str += f' + {model.bias.item()}'

    try:
        display(Markdown(f'${equation_str}$'))
    except NameError:
        print(equation_str)

# %%
print_model_linear_func()
# Out:
# $f(x) = 0.27x_1 + 0.29x_2 + -0.08x_3 + 0.32x_4 + -0.08x_5 + 0.07x_6 + -0.17x_7 + 0.21x_8 + 0.31167247891426086$

# %% [markdown]
# ## Exploring a model

# %%
model.weight
# Out:
# Parameter containing:
# tensor([[ 0.2703,  0.2935, -0.0828,  0.3248, -0.0775,  0.0713, -0.1721,  0.2076]],
#        requires_grad=True)

# %%
model.bias
# Out:
# Parameter containing:
# tensor([0.3117], requires_grad=True)

# %%
for param in model.parameters():
    print(param)
# Out:
# Parameter containing:
# tensor([[ 0.2703,  0.2935, -0.0828,  0.3248, -0.0775,  0.0713, -0.1721,  0.2076]],
#        requires_grad=True)
# Parameter containing:
# tensor([0.3117], requires_grad=True)

# %%
for param in model.named_parameters():
    print(param)
# Out:
# ('weight', Parameter containing:
# tensor([[ 0.2703,  0.2935, -0.0828,  0.3248, -0.0775,  0.0713, -0.1721,  0.2076]],
#        requires_grad=True))
# ('bias', Parameter containing:
# tensor([0.3117], requires_grad=True))

# %%
model(X_train[:2])  # make predictions
# Out:
# tensor([[0.6524],
#         [0.5043]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# Aurélien Géron. Hands On Machine Learning. p. 553:
#
# > When we use a module as a function, PyTorch internally **calls the module’s forward()** method. In the case of the nn.Linear module, the forward() method computes `X @ self.weight.T + self.bias` (where `X` is the input). That’s just what we need for linear regression!

# %% [markdown]
# ## Optimizer and Loss function

# %%
print(f'{learning_rate=}')
print(f'{n_epochs=}')
# Out:
# learning_rate=0.4
# n_epochs=100

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
mse = nn.MSELoss()

# %%
def train_bgd(model, optimizer, criterion, X_train, y_train, n_epochs):
    for epoch in range(n_epochs):
        y_pred = model(X_train)

        loss = criterion(y_pred, y_train)  # calculate loss function
        loss.backward()

        optimizer.step()  # update parameters with grad
        optimizer.zero_grad()  # reset grad
        
        print(f"Epoch {epoch + 1:3}/{n_epochs}, Loss: {loss.item()}")

# %%
train_bgd(model, optimizer, mse, X_train, y_train, n_epochs)
# Out:
# Epoch   1/100, Loss: 4.27860164642334
# Epoch   2/100, Loss: 0.7788285613059998
# Epoch   3/100, Loss: 0.6250892877578735
# Epoch   4/100, Loss: 0.605811595916748
# Epoch   5/100, Loss: 0.5953069925308228
# Epoch   6/100, Loss: 0.5868978500366211
# Epoch   7/100, Loss: 0.5797048211097717
# Epoch   8/100, Loss: 0.5734245777130127
# Epoch   9/100, Loss: 0.5678966045379639
# Epoch  10/100, Loss: 0.56301349401474
# Epoch  11/100, Loss: 0.5586923956871033
# Epoch  12/100, Loss: 0.5548644661903381
# Epoch  13/100, Loss: 0.5514711737632751
# Epoch  14/100, Loss: 0.5484612584114075
# Epoch  15/100, Loss: 0.545789897441864
# Epoch  16/100, Loss: 0.5434176921844482
# Epoch  17/100, Loss: 0.5413098335266113
# Epoch  18/100, Loss: 0.5394359230995178
# Epoch  19/100, Loss: 0.5377690196037292
# Epoch  20/100, Loss: 0.5362852215766907
# Epoch  21/100, Loss: 0.5349637269973755
# Epoch  22/100, Loss: 0.5337859392166138
# Epoch  23/100, Loss: 0.5327355861663818
# Epoch  24/100, Loss: 0.531798243522644
# Epoch  25/100, Loss: 0.5309612154960632
# Epoch  26/100, Loss: 0.5302131772041321
# Epoch  27/100, Loss: 0.5295442938804626
# Epoch  28/100, Loss: 0.5289456248283386
# Epoch  29/100, Loss: 0.5284096002578735
# Epoch  30/100, Loss: 0.5279291272163391
# Epoch  31/100, Loss: 0.527498185634613
# Epoch  32/100, Loss: 0.5271114706993103
# Epoch  33/100, Loss: 0.5267639756202698
# Epoch  34/100, Loss: 0.5264517068862915
# Epoch  35/100, Loss: 0.5261707305908203
# Epoch  36/100, Loss: 0.5259178280830383
# Epoch  37/100, Loss: 0.5256898403167725
# Epoch  38/100, Loss: 0.5254843235015869
# Epoch  39/100, Loss: 0.5252988934516907
# Epoch  40/100, Loss: 0.525131344795227
# Epoch  41/100, Loss: 0.5249799489974976
# Epoch  42/100, Loss: 0.5248430371284485
# Epoch  43/100, Loss: 0.5247190594673157
# Epoch  44/100, Loss: 0.5246067047119141
# Epoch  45/100, Loss: 0.5245049595832825
# Epoch  46/100, Loss: 0.5244125723838806
# Epoch  47/100, Loss: 0.5243287086486816
# Epoch  48/100, Loss: 0.5242524743080139
# Epoch  49/100, Loss: 0.5241832137107849
# Epoch  50/100, Loss: 0.5241202116012573
# Epoch  51/100, Loss: 0.5240627527236938
# Epoch  52/100, Loss: 0.5240104794502258
# Epoch  53/100, Loss: 0.5239627957344055
# Epoch  54/100, Loss: 0.5239192843437195
# Epoch  55/100, Loss: 0.5238795876502991
# Epoch  56/100, Loss: 0.5238432884216309
# Epoch  57/100, Loss: 0.5238101482391357
# Epoch  58/100, Loss: 0.5237798690795898
# Epoch  59/100, Loss: 0.5237520933151245
# Epoch  60/100, Loss: 0.5237267017364502
# Epoch  61/100, Loss: 0.5237034559249878
# Epoch  62/100, Loss: 0.5236820578575134
# Epoch  63/100, Loss: 0.5236625075340271
# Epoch  64/100, Loss: 0.5236445665359497
# Epoch  65/100, Loss: 0.5236281156539917
# Epoch  66/100, Loss: 0.5236130356788635
# Epoch  67/100, Loss: 0.5235990881919861
# Epoch  68/100, Loss: 0.5235863327980042
# Epoch  69/100, Loss: 0.5235745906829834
# Epoch  70/100, Loss: 0.5235637426376343
# Epoch  71/100, Loss: 0.5235538482666016
# Epoch  72/100, Loss: 0.5235447287559509
# Epoch  73/100, Loss: 0.5235362648963928
# Epoch  74/100, Loss: 0.5235284566879272
# Epoch  75/100, Loss: 0.523521363735199
# Epoch  76/100, Loss: 0.5235148072242737
# Epoch  77/100, Loss: 0.5235087275505066
# Epoch  78/100, Loss: 0.5235031843185425
# Epoch  79/100, Loss: 0.5234979391098022
# Epoch  80/100, Loss: 0.5234931707382202
# Epoch  81/100, Loss: 0.5234888195991516
# Epoch  82/100, Loss: 0.5234847664833069
# Epoch  83/100, Loss: 0.523481011390686
# Epoch  84/100, Loss: 0.5234774947166443
# Epoch  85/100, Loss: 0.5234742760658264
# Epoch  86/100, Loss: 0.5234714150428772
# Epoch  87/100, Loss: 0.5234686136245728
# Epoch  88/100, Loss: 0.5234661102294922
# Epoch  89/100, Loss: 0.5234637260437012
# Epoch  90/100, Loss: 0.523461639881134
# Epoch  91/100, Loss: 0.5234596729278564
# Epoch  92/100, Loss: 0.5234577655792236
# Epoch  93/100, Loss: 0.5234560966491699
# Epoch  94/100, Loss: 0.5234545469284058
# Epoch  95/100, Loss: 0.5234530568122864
# Epoch  96/100, Loss: 0.5234516859054565
# Epoch  97/100, Loss: 0.523450493812561
# Epoch  98/100, Loss: 0.5234493017196655
# Epoch  99/100, Loss: 0.5234482884407043
# Epoch 100/100, Loss: 0.5234472155570984

# %%
print_model_linear_func()
# Out:
# $f(x) = 0.85x_1 + 0.12x_2 + -0.32x_3 + 0.36x_4 + -0.00x_5 + -0.05x_6 + -0.89x_7 + -0.86x_8 + 2.069737434387207$

# %% [markdown]
# ### Prediction

# %%
X_new = X_test[:3]
X_new
# Out:
# tensor([[-1.1522, -0.2859, -0.5005, -0.1674, -0.0279,  0.0772,  0.1947,  0.2852],
#         [-0.7065,  0.1102, -0.1620,  0.2087,  0.1230, -0.0343, -0.2362,  0.0602],
#         [-0.2091,  1.8527, -0.5864,  0.1920, -0.0995, -0.1572,  1.0096, -1.4302]])

# %%
with torch.no_grad():
    y_pred = model(X_new)

# %%
y_pred
# Out:
# tensor([[0.7285],
#         [1.7669],
#         [2.7148]])

# %% [markdown]
# ### Evaluating

# %%
with torch.no_grad():
    y_pred = model(X_test)

# %%
print('RMSE:', np.sqrt(mean_squared_error(y_test.numpy(), y_pred.numpy())).item())
print('  r²:', r2_score(y_test.numpy(), y_pred.numpy()))
# Out:
# RMSE: 0.735153799833295
#   r²: 0.5915631055831909

# %% [markdown]
# <hr>

# %% [markdown]
# # Conclusion

# %% [markdown]
# Comparison between the codes:
#
# **Only tensors and Autograd:**
#
# ```python
# for epoch in range(n_epochs):
#     y_pred = X_train @ weights + bias             # 1. Predictions calculated directly
#
#     loss = ((y_pred - y_train) ** 2).mean()       # 2. Loss calculated directly
#     loss.backward()
#
#     with torch.no_grad():                         # 3. Manually passing context
#         bias -= learning_rate * bias.grad         #    bias update
#         weights -= learning_rate * weights.grad   #    weights update
#         bias.grad.zero_()                         #    bias zero grad
#         weights.grad.zero_()                      #    weights zero grad
# ```
#
# **High-level API:**
#
# ```python
# for epoch in range(n_epochs):
#     y_pred = model(X_train)                       # 1. Calculated through model()
#
#     loss = criterion(y_pred, y_train)             # 2. Calculated through nn.MSE() module
#     loss.backward()
#
#     optimizer.step()                              # 3. weights and bias update in no_grad() context
#     optimizer.zero_grad()                         #    weights and bias zero grad in no_grad() context
# ```

# %%
# tensors and Autograd
print_linear_func()
# Out:
# $f(x) = 0.86x_1 + 0.12x_2 + -0.32x_3 + 0.37x_4 + -0.00x_5 + -0.05x_6 + -0.88x_7 + -0.86x_8 + 2.069737434387207$

# %%
# High-level API
print_model_linear_func()
# Out:
# $f(x) = 0.85x_1 + 0.12x_2 + -0.32x_3 + 0.36x_4 + -0.00x_5 + -0.05x_6 + -0.89x_7 + -0.86x_8 + 2.069737434387207$
